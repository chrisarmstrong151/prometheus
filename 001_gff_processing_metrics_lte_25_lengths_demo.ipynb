# %% [markdown]
# # Intermediate states demo (DOES NOT WORK)

# %% [markdown]
# Show the distribution for various genes given their intronic combinations.

# %% [markdown]
# # Libraries

# %%
# Libraries


# Pandas
import pandas as pd

# Plotting
# Source: https://matplotlib.org/stable/gallery/statistics/hist.html#histograms
import matplotlib.pyplot as plt
import numpy as np

# %%
# Set the data folder.
data_folder = '/media/apollo/Samsung_T5/transfer/mayur/'
# data_folder = '/home/mad1188/rvallsamples/'

# %% [markdown]
# # Intermediate states

# %% [markdown]
# First, read in the intermediate states.

# %%
# Intermediate states.

# Skip the metadata lines (1-9).
df = pd.read_csv(
    data_folder + 'intermediate_states.tsv',
    sep = '\t'
)
# Out:
# /tmp/ipykernel_7957/1386855694.py:4: DtypeWarning: Columns (1,2,3,4,5,6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
df
# Out:
#            transcript_id minimum_transcript_length maximum_transcript_length  \
# 0         NM_001242532.5                      2573                     41223
# 1         NM_001242532.5                      2573                     41223
# 2         NM_001242532.5                      2573                     41223
# 3         NM_001242532.5                      2573                     41223
# 4         NM_001242532.5                      2573                     41223
# ...                  ...                       ...                       ...
# 16921800  XM_011509770.4                      6292                    115287
# 16921801  XM_047431038.1                      4352                     22071
# 16921802  XM_047431038.1                      4352                     22071
# 16921803  XM_047431038.1                      4352                     22071
# 16921804  XM_047431038.1                      4352                     22071
#
# ...

# %%
set(df.transcript_id)
# Out:
# {'NM_001242532.5',
#  'NM_001346317.2',
#  'NM_001346398.2',
#  'NM_001368908.2',
#  'NM_018145.3',
#  'NR_073449.2',
#  'NR_183316.1',
#  'XM_011509770.4',
#  'XM_047431038.1',
#  'XM_047433905.1',
#  'transcript_id'}

# %% [markdown]
# Let's work with *PAX6* and *ATG13* for the analysis.

# %%
# Restrict to PAX6.
pax6 = df[df.transcript_id == 'NM_001368908.2'].copy()

# Restrict to ATG13.
atg13 = df[df.transcript_id == 'NM_001346317.2'].copy()

# %%
pax6
# Out:
#          transcript_id minimum_transcript_length maximum_transcript_length  \
# 139465  NM_001368908.2                      2393                     19604
# 139466  NM_001368908.2                      2393                     19604
# 139467  NM_001368908.2                      2393                     19604
# 139468  NM_001368908.2                      2393                     19604
# 139469  NM_001368908.2                      2393                     19604
# ...                ...                       ...                       ...
# 140484  NM_001368908.2                      2393                     19604
# 140485  NM_001368908.2                      2393                     19604
# 140486  NM_001368908.2                      2393                     19604
# 140487  NM_001368908.2                      2393                     19604
# 140488  NM_001368908.2                      2393                     19604
#
# ...

# %%
atg13
# Out:
#          transcript_id minimum_transcript_length maximum_transcript_length  \
# 4096    NM_001346317.2                      4163                     56966
# 4097    NM_001346317.2                      4163                     56966
# 4098    NM_001346317.2                      4163                     56966
# 4099    NM_001346317.2                      4163                     56966
# 4100    NM_001346317.2                      4163                     56966
# ...                ...                       ...                       ...
# 135163  NM_001346317.2                      4163                     56966
# 135164  NM_001346317.2                      4163                     56966
# 135165  NM_001346317.2                      4163                     56966
# 135166  NM_001346317.2                      4163                     56966
# 135167  NM_001346317.2                      4163                     56966
#
# ...

# %% [markdown]
# # Graphing

# %%
N_points = 100000
n_bins = 20

# Create a random number generator with a fixed seed for reproducibility
rng = np.random.default_rng(19680801)

dist1 = rng.standard_normal(N_points)
dist2 = 0.4 * rng.standard_normal(N_points) + 5

# %% [markdown]
# Produce a simple histogram.

# %%
n_bins = 20

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)

# We can set the number of bins with the *bins* keyword argument.
axs[0].hist(np.asarray(list(pax6.intermediate_transcript_length)), bins=n_bins)
axs[1].hist(np.asarray(list(atg13.intermediate_transcript_length)), bins=n_bins)
# Out:
# (array([4725., 6294., 6841., 8095., 6923., 8256., 7900., 8483., 8010.,
#         8444., 8015., 7720., 8079., 6729., 6551., 5805., 5110., 3857.,
#         3013., 2222.]),
#  array([    0.  ,  1858.55,  3717.1 ,  5575.65,  7434.2 ,  9292.75,
#         11151.3 , 13009.85, 14868.4 , 16726.95, 18585.5 , 20444.05,
#         22302.6 , 24161.15, 26019.7 , 27878.25, 29736.8 , 31595.35,
#         33453.9 , 35312.45, 37171.  ]),
#  <BarContainer object of 20 artists>)
# Error in callback <function _draw_all_if_interactive at 0x7a4e091b9620> (for post_execute):
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x7a4de8d8d080> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/mosaic/envs/3d_rna_velocity/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
# ...
