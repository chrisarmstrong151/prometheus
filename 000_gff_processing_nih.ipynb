# %% [markdown]
# # GFF Processing

# %% [markdown]
# Both NIH (https://ftp.ncbi.nlm.nih.gov/genomes/all/annotation_releases/9606/GCF_000001405.40-RS_2023_10/) and Ensembl (https://ftp.ensembl.org/pub/release-107/gff3/homo_sapiens/) provide GFF files for annotation of the human genome.  However, the annotations are not replicas of each other, nor are they constrained to only protein-coding annotations.  Thus, we will do some processing here to get a usable annotation file which can be used in our package.

# %% [markdown]
# # TODO: Add gene length information (not just transcript length)?

# %% [markdown]
# # TODO: Add isoform information

# %% [markdown]
# # Libraries

# %%
# Libraries


# Pandas
import pandas as pd

# %%
# Set the data folder.
data_folder = '/media/apollo/Samsung_T5/transfer/mayur/annotations/'
# data_folder = '/home/mad1188/rvallsamples/'

# %% [markdown]
# # NIH Processing

# %% [markdown]
# First, read in the GFF file from NIH.

# %%
# Set the file name.
filename = 'GCF_000001405.40_GRCh38.p14_genomic.gff'

# %%
# NIH file.

# Skip the metadata lines (1-9).
df = pd.read_csv(
    data_folder + filename, 
    header = None,
    sep = '\t', 
    skiprows = 9
)

# %% [markdown]
# There is a slight quirk because of how Pandas reads in the data, so remove the last row.

# %%
# Drop the last row.
df = df[0:len(df)-1]

# %% [markdown]
# Set the column names.

# %%
# Column names.
df.columns = ['nih_molecule_accession', 'source', 'category', 'start', 'stop', 'dummy_one', 'strand', 'dummy_two', 'information']

# %%
df
# Out:
#         nih_molecule_accession      source    category    start         stop  \
# 0                 NC_000001.11      RefSeq      region      1.0  248956422.0
# 1                 NC_000001.11  BestRefSeq  pseudogene  11874.0      14409.0
# 2                 NC_000001.11  BestRefSeq  transcript  11874.0      14409.0
# 3                 NC_000001.11  BestRefSeq        exon  11874.0      12227.0
# 4                 NC_000001.11  BestRefSeq        exon  12613.0      12721.0
# ...                        ...         ...         ...      ...          ...
# 4901538            NC_012920.1      RefSeq        exon  15888.0      15953.0
# 4901539            NC_012920.1      RefSeq        gene  15956.0      16023.0
# 4901540            NC_012920.1      RefSeq        tRNA  15956.0      16023.0
# 4901541            NC_012920.1      RefSeq        exon  15956.0      16023.0
# 4901542            NC_012920.1      RefSeq      D_loop  16024.0      17145.0
#
#         dummy_one strand dummy_two  \
# 0               .      +         .
# 1               .      +         .
# 2               .      +         .
# 3               .      +         .
# 4               .      +         .
# ...           ...    ...       ...
# 4901538         .      +         .
# 4901539         .      -         .
# 4901540         .      -         .
# 4901541         .      -         .
# 4901542         .      -         .
#
#                                                information
# 0        ID=NC_000001.11:1..248956422;Dbxref=taxon:9606...
# 1        ID=gene-DDX11L1;Dbxref=GeneID:100287102,HGNC:H...
# 2        ID=rna-NR_046018.2;Parent=gene-DDX11L1;Dbxref=...
# 3        ID=exon-NR_046018.2-1;Parent=rna-NR_046018.2;D...
# 4        ID=exon-NR_046018.2-2;Parent=rna-NR_046018.2;D...
# ...                                                    ...
# 4901538  ID=exon-TRNT-1;Parent=rna-TRNT;Dbxref=GeneID:4...
# 4901539  ID=gene-TRNP;Dbxref=GeneID:4571,HGNC:HGNC:7494...
# 4901540  ID=rna-TRNP;Parent=gene-TRNP;Dbxref=GeneID:457...
# 4901541  ID=exon-TRNP-1;Parent=rna-TRNP;Dbxref=GeneID:4...
# 4901542            ID=id-NC_012920.1:1..16569;gbkey=D-loop
#
# [4901543 rows x 9 columns]

# %% [markdown]
# Immediately drop the dummy columns.

# %%
# No dummy columns required.
df = df.drop(columns = ['dummy_one', 'dummy_two'])

# %%
# set(list(df['category']))

# %% [markdown]
# As we are only concerned with high-quality annotations, we will restrict the genome to "Complete genome" annotations, see https://www.ncbi.nlm.nih.gov/assembly/help/#resultsfields

# %%
# Complete genome only.
# Source: https://stackoverflow.com/a/11531402
df = df[df['nih_molecule_accession'].str.contains("NC")]

# %% [markdown]
# Restrict to only exons.

# %%
# Basic restriction with a copy so we can add
# columns below.
restricted = df[df.category.isin(['exon'])].copy()

# %%
restricted
# Out:
#         nih_molecule_accession      source category    start     stop strand  \
# 3                 NC_000001.11  BestRefSeq     exon  11874.0  12227.0      +
# 4                 NC_000001.11  BestRefSeq     exon  12613.0  12721.0      +
# 5                 NC_000001.11  BestRefSeq     exon  13221.0  14409.0      +
# 8                 NC_000001.11  BestRefSeq     exon  29321.0  29370.0      -
# 9                 NC_000001.11  BestRefSeq     exon  24738.0  24891.0      -
# ...                        ...         ...      ...      ...      ...    ...
# 4901527            NC_012920.1      RefSeq     exon  14149.0  14673.0      -
# 4901531            NC_012920.1      RefSeq     exon  14674.0  14742.0      -
# 4901534            NC_012920.1      RefSeq     exon  14747.0  15887.0      +
# 4901538            NC_012920.1      RefSeq     exon  15888.0  15953.0      +
# 4901541            NC_012920.1      RefSeq     exon  15956.0  16023.0      -
#
#                                                information
# 3        ID=exon-NR_046018.2-1;Parent=rna-NR_046018.2;D...
# 4        ID=exon-NR_046018.2-2;Parent=rna-NR_046018.2;D...
# 5        ID=exon-NR_046018.2-3;Parent=rna-NR_046018.2;D...
# 8        ID=exon-NR_024540.1-1;Parent=rna-NR_024540.1;D...
# 9        ID=exon-NR_024540.1-2;Parent=rna-NR_024540.1;D...
# ...                                                    ...
# 4901527  ID=exon-ND6-1;Parent=rna-ND6;Dbxref=GeneID:454...
# 4901531  ID=exon-TRNE-1;Parent=rna-TRNE;Dbxref=GeneID:4...
# 4901534  ID=exon-CYTB-1;Parent=rna-CYTB;Dbxref=GeneID:4...
# 4901538  ID=exon-TRNT-1;Parent=rna-TRNT;Dbxref=GeneID:4...
# 4901541  ID=exon-TRNP-1;Parent=rna-TRNP;Dbxref=GeneID:4...
#
# [2111877 rows x 7 columns]

# %% [markdown]
# Take a look at the string structure to help us parse below.

# %%
list(restricted.information[:1])
# Out:
# ['ID=exon-NR_046018.2-1;Parent=rna-NR_046018.2;Dbxref=GeneID:100287102,GenBank:NR_046018.2,HGNC:HGNC:37102;gbkey=misc_RNA;gene=DDX11L1;product=DEAD/H-box helicase 11 like 1 (pseudogene);pseudo=true;transcript_id=NR_046018.2']

# %% [markdown]
# Go row-by-row and split on the semicolon, keeping the exon ID, the parent, the RNA key, the gene, the pseudogene status, and the transcript ID.  This is **expensive** to do because the row format is not consistent across records.

# %%
# No need for speculative annotations.
# Source: https://stackoverflow.com/a/39949288
# patternDel = "experiment="
# filter = restricted[3].str.contains(patternDel)

# restricted = restricted[~filter]

# %%
# restricted

# %%
# Make a dictionary to hold all the lists for the DataFrame.
dataframe_dict = {
    'ID': [],
    'exon_parent': [],
    'exon_gbkey': [],
    'exon_gene': [],
    'exon_transcript_id': []
}

# Go row-by-row.
for row in list(restricted.information):
    
    # Skip the record if the evidence is conjectural.
    if 'experiment=' not in row:
    
        # Split the row.
        split_up = row.split(';')

        # Define variables to hold the information.
        ID = ''
        exon_parent = ''
        exon_gbkey = ''
        exon_gene = ''
        exon_pseudo = False
        exon_transcript_id = ''

        # Now go over each element in the split.
        for su in split_up:

            # Split on the '='.
            sub_split_up = su.split('=')

            # Anything useful?
            if sub_split_up[0] == 'ID':
                ID = sub_split_up[1]
            if sub_split_up[0] == 'Parent':
                exon_parent = sub_split_up[1]
            elif sub_split_up[0] == 'gbkey':
                exon_gbkey = sub_split_up[1]
            elif sub_split_up[0] == 'gene':
                exon_gene = sub_split_up[1]
            elif sub_split_up[0] == 'pseudo':
                exon_pseudo = True
            elif sub_split_up[0] == 'transcript_id':
                exon_transcript_id = sub_split_up[1]

        # If no psuedogene, record the information.
        if exon_pseudo == False:
            dataframe_dict['ID'].append(ID)
            dataframe_dict['exon_parent'].append(exon_parent)
            dataframe_dict['exon_gbkey'].append(exon_gbkey)
            dataframe_dict['exon_gene'].append(exon_gene)
            dataframe_dict['exon_transcript_id'].append(exon_transcript_id)
        else:
            dataframe_dict['ID'].append('unusable')
            dataframe_dict['exon_parent'].append('unusable')
            dataframe_dict['exon_gbkey'].append('unusable')
            dataframe_dict['exon_gene'].append('unusable')
            dataframe_dict['exon_transcript_id'].append('unusable')
    
    else:
        
        # Record unusable.
        dataframe_dict['ID'].append('unusable')
        dataframe_dict['exon_parent'].append('unusable')
        dataframe_dict['exon_gbkey'].append('unusable')
        dataframe_dict['exon_gene'].append('unusable')
        dataframe_dict['exon_transcript_id'].append('unusable')

# Create the DataFrame.
restricted_df = pd.DataFrame(
    data = dataframe_dict
)

# %%
restricted_df
# Out:
#                   ID exon_parent exon_gbkey exon_gene exon_transcript_id
# 0           unusable    unusable   unusable  unusable           unusable
# 1           unusable    unusable   unusable  unusable           unusable
# 2           unusable    unusable   unusable  unusable           unusable
# 3           unusable    unusable   unusable  unusable           unusable
# 4           unusable    unusable   unusable  unusable           unusable
# ...              ...         ...        ...       ...                ...
# 2111872   exon-ND6-1     rna-ND6       mRNA       ND6
# 2111873  exon-TRNE-1    rna-TRNE       tRNA      TRNE
# 2111874  exon-CYTB-1    rna-CYTB       mRNA      CYTB
# 2111875  exon-TRNT-1    rna-TRNT       tRNA      TRNT
# 2111876  exon-TRNP-1    rna-TRNP       tRNA      TRNP
#
# [2111877 rows x 5 columns]

# %% [markdown]
# Do a quick and dirty "join" which avoids the headache of the index.

# %%
restricted['ID'] = list(restricted_df['ID'])
restricted['exon_parent'] = list(restricted_df['exon_parent'])
restricted['exon_gbkey'] = list(restricted_df['exon_gbkey'])
restricted['exon_gene'] = list(restricted_df['exon_gene'])
restricted['exon_transcript_id'] = list(restricted_df['exon_transcript_id'])

# %%
restricted
# Out:
#         nih_molecule_accession      source category    start     stop strand  \
# 3                 NC_000001.11  BestRefSeq     exon  11874.0  12227.0      +
# 4                 NC_000001.11  BestRefSeq     exon  12613.0  12721.0      +
# 5                 NC_000001.11  BestRefSeq     exon  13221.0  14409.0      +
# 8                 NC_000001.11  BestRefSeq     exon  29321.0  29370.0      -
# 9                 NC_000001.11  BestRefSeq     exon  24738.0  24891.0      -
# ...                        ...         ...      ...      ...      ...    ...
# 4901527            NC_012920.1      RefSeq     exon  14149.0  14673.0      -
# 4901531            NC_012920.1      RefSeq     exon  14674.0  14742.0      -
# 4901534            NC_012920.1      RefSeq     exon  14747.0  15887.0      +
# 4901538            NC_012920.1      RefSeq     exon  15888.0  15953.0      +
# 4901541            NC_012920.1      RefSeq     exon  15956.0  16023.0      -
#
#                                                information           ID  \
# 3        ID=exon-NR_046018.2-1;Parent=rna-NR_046018.2;D...     unusable
# 4        ID=exon-NR_046018.2-2;Parent=rna-NR_046018.2;D...     unusable
# 5        ID=exon-NR_046018.2-3;Parent=rna-NR_046018.2;D...     unusable
# 8        ID=exon-NR_024540.1-1;Parent=rna-NR_024540.1;D...     unusable
# 9        ID=exon-NR_024540.1-2;Parent=rna-NR_024540.1;D...     unusable
# ...                                                    ...          ...
# 4901527  ID=exon-ND6-1;Parent=rna-ND6;Dbxref=GeneID:454...   exon-ND6-1
# 4901531  ID=exon-TRNE-1;Parent=rna-TRNE;Dbxref=GeneID:4...  exon-TRNE-1
# 4901534  ID=exon-CYTB-1;Parent=rna-CYTB;Dbxref=GeneID:4...  exon-CYTB-1
# 4901538  ID=exon-TRNT-1;Parent=rna-TRNT;Dbxref=GeneID:4...  exon-TRNT-1
# 4901541  ID=exon-TRNP-1;Parent=rna-TRNP;Dbxref=GeneID:4...  exon-TRNP-1
#
#         exon_parent exon_gbkey exon_gene exon_transcript_id
# 3          unusable   unusable  unusable           unusable
# 4          unusable   unusable  unusable           unusable
# 5          unusable   unusable  unusable           unusable
# 8          unusable   unusable  unusable           unusable
# 9          unusable   unusable  unusable           unusable
# ...             ...        ...       ...                ...
# 4901527     rna-ND6       mRNA       ND6
# 4901531    rna-TRNE       tRNA      TRNE
# 4901534    rna-CYTB       mRNA      CYTB
# 4901538    rna-TRNT       tRNA      TRNT
# 4901541    rna-TRNP       tRNA      TRNP
#
# [2111877 rows x 12 columns]

# %% [markdown]
# Get rid of anything unusable.

# %%
# Only usable material.
restricted = restricted[restricted.ID != 'unusable'].copy()

# %%
restricted
# Out:
#         nih_molecule_accession      source category    start     stop strand  \
# 21                NC_000001.11  BestRefSeq     exon  17369.0  17436.0      -
# 23                NC_000001.11  BestRefSeq     exon  17369.0  17391.0      -
# 25                NC_000001.11  BestRefSeq     exon  17409.0  17431.0      -
# 30                NC_000001.11      Gnomon     exon  29774.0  30667.0      +
# 31                NC_000001.11      Gnomon     exon  30976.0  31093.0      +
# ...                        ...         ...      ...      ...      ...    ...
# 4901527            NC_012920.1      RefSeq     exon  14149.0  14673.0      -
# 4901531            NC_012920.1      RefSeq     exon  14674.0  14742.0      -
# 4901534            NC_012920.1      RefSeq     exon  14747.0  15887.0      +
# 4901538            NC_012920.1      RefSeq     exon  15888.0  15953.0      +
# 4901541            NC_012920.1      RefSeq     exon  15956.0  16023.0      -
#
#                                                information  \
# 21       ID=exon-NR_106918.1-1;Parent=rna-NR_106918.1;D...
# 23       ID=exon-MIR6859-1-1;Parent=rna-MIR6859-1;Dbxre...
# 25       ID=exon-MIR6859-1-2-1;Parent=rna-MIR6859-1-2;D...
# 30       ID=exon-XR_007065314.1-1;Parent=rna-XR_0070653...
# 31       ID=exon-XR_007065314.1-2;Parent=rna-XR_0070653...
# ...                                                    ...
# 4901527  ID=exon-ND6-1;Parent=rna-ND6;Dbxref=GeneID:454...
# 4901531  ID=exon-TRNE-1;Parent=rna-TRNE;Dbxref=GeneID:4...
# 4901534  ID=exon-CYTB-1;Parent=rna-CYTB;Dbxref=GeneID:4...
# 4901538  ID=exon-TRNT-1;Parent=rna-TRNT;Dbxref=GeneID:4...
# 4901541  ID=exon-TRNP-1;Parent=rna-TRNP;Dbxref=GeneID:4...
#
#                             ID         exon_parent     exon_gbkey  \
# 21          exon-NR_106918.1-1     rna-NR_106918.1  precursor_RNA
# 23            exon-MIR6859-1-1       rna-MIR6859-1          ncRNA
# 25          exon-MIR6859-1-2-1     rna-MIR6859-1-2          ncRNA
# 30       exon-XR_007065314.1-1  rna-XR_007065314.1          ncRNA
# 31       exon-XR_007065314.1-2  rna-XR_007065314.1          ncRNA
# ...                        ...                 ...            ...
# 4901527             exon-ND6-1             rna-ND6           mRNA
# 4901531            exon-TRNE-1            rna-TRNE           tRNA
# 4901534            exon-CYTB-1            rna-CYTB           mRNA
# 4901538            exon-TRNT-1            rna-TRNT           tRNA
# 4901541            exon-TRNP-1            rna-TRNP           tRNA
#
#            exon_gene exon_transcript_id
# 21         MIR6859-1        NR_106918.1
# 23         MIR6859-1
# 25         MIR6859-1
# 30       MIR1302-2HG     XR_007065314.1
# 31       MIR1302-2HG     XR_007065314.1
# ...              ...                ...
# 4901527          ND6
# 4901531         TRNE
# 4901534         CYTB
# 4901538         TRNT
# 4901541         TRNP
#
# [1698719 rows x 12 columns]

# %% [markdown]
# See what actually has a transcript.

# %%
# Only concerned with known transcripts.
has_transcript = restricted[restricted.exon_transcript_id != ''].copy()

# %%
has_transcript
# Out:
#         nih_molecule_accession      source category       start        stop  \
# 21                NC_000001.11  BestRefSeq     exon     17369.0     17436.0
# 30                NC_000001.11      Gnomon     exon     29774.0     30667.0
# 31                NC_000001.11      Gnomon     exon     30976.0     31093.0
# 32                NC_000001.11      Gnomon     exon     34168.0     35418.0
# 35                NC_000001.11  BestRefSeq     exon     30366.0     30503.0
# ...                        ...         ...      ...         ...         ...
# 4464014           NC_000024.10      Gnomon     exon  57192325.0  57192537.0
# 4464015           NC_000024.10      Gnomon     exon  57194043.0  57194127.0
# 4464016           NC_000024.10      Gnomon     exon  57196336.0  57197337.0
# 4464022           NC_000024.10  BestRefSeq     exon  57203182.0  57203350.0
# 4464023           NC_000024.10  BestRefSeq     exon  57201084.0  57202145.0
#
#         strand                                        information  \
# 21           -  ID=exon-NR_106918.1-1;Parent=rna-NR_106918.1;D...
# 30           +  ID=exon-XR_007065314.1-1;Parent=rna-XR_0070653...
# 31           +  ID=exon-XR_007065314.1-2;Parent=rna-XR_0070653...
# 32           +  ID=exon-XR_007065314.1-3;Parent=rna-XR_0070653...
# 35           +  ID=exon-NR_036051.1-1;Parent=rna-NR_036051.1;D...
# ...        ...                                                ...
# 4464014      +  ID=exon-XM_017030055.2-1;Parent=rna-XM_0170300...
# 4464015      +  ID=exon-XM_017030055.2-2;Parent=rna-XM_0170300...
# 4464016      +  ID=exon-XM_017030055.2-3;Parent=rna-XM_0170300...
# 4464022      -  ID=exon-NR_138048.1-2-1;Parent=rna-NR_138048.1...
# 4464023      -  ID=exon-NR_138048.1-2-2;Parent=rna-NR_138048.1...
#
#                             ID         exon_parent     exon_gbkey  \
# 21          exon-NR_106918.1-1     rna-NR_106918.1  precursor_RNA
# 30       exon-XR_007065314.1-1  rna-XR_007065314.1          ncRNA
# 31       exon-XR_007065314.1-2  rna-XR_007065314.1          ncRNA
# 32       exon-XR_007065314.1-3  rna-XR_007065314.1          ncRNA
# 35          exon-NR_036051.1-1     rna-NR_036051.1  precursor_RNA
# ...                        ...                 ...            ...
# 4464014  exon-XM_017030055.2-1  rna-XM_017030055.2           mRNA
# 4464015  exon-XM_017030055.2-2  rna-XM_017030055.2           mRNA
# 4464016  exon-XM_017030055.2-3  rna-XM_017030055.2           mRNA
# 4464022   exon-NR_138048.1-2-1   rna-NR_138048.1-2          ncRNA
# 4464023   exon-NR_138048.1-2-2   rna-NR_138048.1-2          ncRNA
#
#            exon_gene exon_transcript_id
# 21         MIR6859-1        NR_106918.1
# 30       MIR1302-2HG     XR_007065314.1
# 31       MIR1302-2HG     XR_007065314.1
# 32       MIR1302-2HG     XR_007065314.1
# 35         MIR1302-2        NR_036051.1
# ...              ...                ...
# 4464014         IL9R     XM_017030055.2
# 4464015         IL9R     XM_017030055.2
# 4464016         IL9R     XM_017030055.2
# 4464022       WASIR1        NR_138048.1
# 4464023       WASIR1        NR_138048.1
#
# [1694667 rows x 12 columns]

# %% [markdown]
# Pick a gene to check our work.

# %%
# TET2 check.

# Note that for predicted products we do not have
# start, stop, or strand information even though
# the gene is known.
restricted[restricted['exon_gene'] == 'TET2']

# with pd.option_context(
#     'display.max_rows', None,
#     'display.max_columns', None,
#     'display.precision', 3,
# ):
#     print(
#         restricted[restricted['exon_gene'] == 'TET2']
#     )
# Out:
#         nih_molecule_accession  source category        start         stop  \
# 1233582           NC_000004.12  Gnomon     exon  105146876.0  105146979.0
# 1233583           NC_000004.12  Gnomon     exon  105190360.0  105190505.0
# 1233584           NC_000004.12  Gnomon     exon  105233897.0  105237351.0
# 1233585           NC_000004.12  Gnomon     exon  105241339.0  105242098.0
# 1233586           NC_000004.12  Gnomon     exon  105242834.0  105242916.0
# ...                        ...     ...      ...          ...          ...
# 1233725           NC_000004.12  Gnomon     exon  105146876.0  105146979.0
# 1233726           NC_000004.12  Gnomon     exon  105190360.0  105190505.0
# 1233727           NC_000004.12  Gnomon     exon  105233897.0  105237351.0
# 1233728           NC_000004.12  Gnomon     exon  105238514.0  105238713.0
# 1233729           NC_000004.12  Gnomon     exon  105241339.0  105241396.0
#
#         strand                                        information  \
# 1233582      +  ID=exon-XR_007057933.1-1;Parent=rna-XR_0070579...
# 1233583      +  ID=exon-XR_007057933.1-2;Parent=rna-XR_0070579...
# 1233584      +  ID=exon-XR_007057933.1-3;Parent=rna-XR_0070579...
# 1233585      +  ID=exon-XR_007057933.1-4;Parent=rna-XR_0070579...
# 1233586      +  ID=exon-XR_007057933.1-5;Parent=rna-XR_0070579...
# ...        ...                                                ...
# 1233725      +  ID=exon-XM_047415842.1-1;Parent=rna-XM_0474158...
# 1233726      +  ID=exon-XM_047415842.1-2;Parent=rna-XM_0474158...
# 1233727      +  ID=exon-XM_047415842.1-3;Parent=rna-XM_0474158...
# 1233728      +  ID=exon-XM_047415842.1-4;Parent=rna-XM_0474158...
# 1233729      +  ID=exon-XM_047415842.1-5;Parent=rna-XM_0474158...
#
#                             ID         exon_parent exon_gbkey exon_gene  \
# 1233582  exon-XR_007057933.1-1  rna-XR_007057933.1   misc_RNA      TET2
# 1233583  exon-XR_007057933.1-2  rna-XR_007057933.1   misc_RNA      TET2
# 1233584  exon-XR_007057933.1-3  rna-XR_007057933.1   misc_RNA      TET2
# 1233585  exon-XR_007057933.1-4  rna-XR_007057933.1   misc_RNA      TET2
# 1233586  exon-XR_007057933.1-5  rna-XR_007057933.1   misc_RNA      TET2
# ...                        ...                 ...        ...       ...
# 1233725  exon-XM_047415842.1-1  rna-XM_047415842.1       mRNA      TET2
# 1233726  exon-XM_047415842.1-2  rna-XM_047415842.1       mRNA      TET2
# 1233727  exon-XM_047415842.1-3  rna-XM_047415842.1       mRNA      TET2
# 1233728  exon-XM_047415842.1-4  rna-XM_047415842.1       mRNA      TET2
# 1233729  exon-XM_047415842.1-5  rna-XM_047415842.1       mRNA      TET2
#
#         exon_transcript_id
# 1233582     XR_007057933.1
# 1233583     XR_007057933.1
# 1233584     XR_007057933.1
# 1233585     XR_007057933.1
# 1233586     XR_007057933.1
# ...                    ...
# 1233725     XM_047415842.1
# 1233726     XM_047415842.1
# 1233727     XM_047415842.1
# 1233728     XM_047415842.1
# 1233729     XM_047415842.1
#
# [83 rows x 12 columns]

# %% [markdown]
# Now we can annotate confirmed vs. predicted RNAs.

# %%
# Predicted - yes or no?

# Source: https://www.ncbi.nlm.nih.gov/books/NBK21091/table/ch18.T.refseq_accession_numbers_and_mole/?report=objectonly
predicted = []

for i in list(restricted['exon_transcript_id']):
    
    # Anything there?
    if len(i) > 0:
    
        # Split and identify.
        split_up = i.split('_')[0]

        if split_up in ['NM', 'NR']:
            predicted.append('no')
        elif split_up in ['XM', 'XR']:
            predicted.append('yes')
    
    else:
        
        # pd.NA as inconsistent beavior ere
        # so set a manual missin value.
        predicted.append('not_available')

# Add to the DataFrame.
restricted['predicted'] = predicted

# %%
restricted
# Out:
#         nih_molecule_accession      source category    start     stop strand  \
# 21                NC_000001.11  BestRefSeq     exon  17369.0  17436.0      -
# 23                NC_000001.11  BestRefSeq     exon  17369.0  17391.0      -
# 25                NC_000001.11  BestRefSeq     exon  17409.0  17431.0      -
# 30                NC_000001.11      Gnomon     exon  29774.0  30667.0      +
# 31                NC_000001.11      Gnomon     exon  30976.0  31093.0      +
# ...                        ...         ...      ...      ...      ...    ...
# 4901527            NC_012920.1      RefSeq     exon  14149.0  14673.0      -
# 4901531            NC_012920.1      RefSeq     exon  14674.0  14742.0      -
# 4901534            NC_012920.1      RefSeq     exon  14747.0  15887.0      +
# 4901538            NC_012920.1      RefSeq     exon  15888.0  15953.0      +
# 4901541            NC_012920.1      RefSeq     exon  15956.0  16023.0      -
#
#                                                information  \
# 21       ID=exon-NR_106918.1-1;Parent=rna-NR_106918.1;D...
# 23       ID=exon-MIR6859-1-1;Parent=rna-MIR6859-1;Dbxre...
# 25       ID=exon-MIR6859-1-2-1;Parent=rna-MIR6859-1-2;D...
# 30       ID=exon-XR_007065314.1-1;Parent=rna-XR_0070653...
# 31       ID=exon-XR_007065314.1-2;Parent=rna-XR_0070653...
# ...                                                    ...
# 4901527  ID=exon-ND6-1;Parent=rna-ND6;Dbxref=GeneID:454...
# 4901531  ID=exon-TRNE-1;Parent=rna-TRNE;Dbxref=GeneID:4...
# 4901534  ID=exon-CYTB-1;Parent=rna-CYTB;Dbxref=GeneID:4...
# 4901538  ID=exon-TRNT-1;Parent=rna-TRNT;Dbxref=GeneID:4...
# 4901541  ID=exon-TRNP-1;Parent=rna-TRNP;Dbxref=GeneID:4...
#
#                             ID         exon_parent     exon_gbkey  \
# 21          exon-NR_106918.1-1     rna-NR_106918.1  precursor_RNA
# 23            exon-MIR6859-1-1       rna-MIR6859-1          ncRNA
# 25          exon-MIR6859-1-2-1     rna-MIR6859-1-2          ncRNA
# 30       exon-XR_007065314.1-1  rna-XR_007065314.1          ncRNA
# 31       exon-XR_007065314.1-2  rna-XR_007065314.1          ncRNA
# ...                        ...                 ...            ...
# 4901527             exon-ND6-1             rna-ND6           mRNA
# 4901531            exon-TRNE-1            rna-TRNE           tRNA
# 4901534            exon-CYTB-1            rna-CYTB           mRNA
# 4901538            exon-TRNT-1            rna-TRNT           tRNA
# 4901541            exon-TRNP-1            rna-TRNP           tRNA
#
#            exon_gene exon_transcript_id      predicted
# 21         MIR6859-1        NR_106918.1             no
# 23         MIR6859-1                     not_available
# 25         MIR6859-1                     not_available
# 30       MIR1302-2HG     XR_007065314.1            yes
# 31       MIR1302-2HG     XR_007065314.1            yes
# ...              ...                ...            ...
# 4901527          ND6                     not_available
# 4901531         TRNE                     not_available
# 4901534         CYTB                     not_available
# 4901538         TRNT                     not_available
# 4901541         TRNP                     not_available
#
# [1698719 rows x 13 columns]

# %% [markdown]
# Pick a gene to check our work.

# %%
# TET2 check.

# Note that for predicted products we do not have
# start, stop, or strand information even though
# the gene is known.
tet_2_check = restricted[restricted['exon_gene'] == 'TET2']
tet_2_check = tet_2_check[tet_2_check['predicted'] == 'no']

# with pd.option_context(
#     'display.max_rows', None,
#     'display.max_columns', None,
#     'display.precision', 3,
# ):
#     print(
#         restricted[restricted['exon_gene'] == 'TET2']
#     )

# %%
tet_2_check
# Out:
#         nih_molecule_accession      source category        start         stop  \
# 1233609           NC_000004.12  BestRefSeq     exon  105145875.0  105146086.0
# 1233610           NC_000004.12  BestRefSeq     exon  105190360.0  105190505.0
# 1233611           NC_000004.12  BestRefSeq     exon  105233897.0  105242771.0
# 1233636           NC_000004.12  BestRefSeq     exon  105146876.0  105146979.0
# 1233637           NC_000004.12  BestRefSeq     exon  105190360.0  105190505.0
# 1233638           NC_000004.12  BestRefSeq     exon  105233897.0  105237351.0
# 1233639           NC_000004.12  BestRefSeq     exon  105241339.0  105241429.0
# 1233640           NC_000004.12  BestRefSeq     exon  105242834.0  105242927.0
# 1233641           NC_000004.12  BestRefSeq     exon  105243570.0  105243778.0
# 1233642           NC_000004.12  BestRefSeq     exon  105259619.0  105259769.0
# 1233643           NC_000004.12  BestRefSeq     exon  105261759.0  105261848.0
# 1233644           NC_000004.12  BestRefSeq     exon  105269610.0  105269747.0
# 1233645           NC_000004.12  BestRefSeq     exon  105272564.0  105272918.0
# 1233646           NC_000004.12  BestRefSeq     exon  105275048.0  105279803.0
#
#         strand                                        information  \
# 1233609      +  ID=exon-NM_017628.4-1;Parent=rna-NM_017628.4;D...
# 1233610      +  ID=exon-NM_017628.4-2;Parent=rna-NM_017628.4;D...
# 1233611      +  ID=exon-NM_017628.4-3;Parent=rna-NM_017628.4;D...
# 1233636      +  ID=exon-NM_001127208.3-1;Parent=rna-NM_0011272...
# 1233637      +  ID=exon-NM_001127208.3-2;Parent=rna-NM_0011272...
# 1233638      +  ID=exon-NM_001127208.3-3;Parent=rna-NM_0011272...
# 1233639      +  ID=exon-NM_001127208.3-4;Parent=rna-NM_0011272...
# 1233640      +  ID=exon-NM_001127208.3-5;Parent=rna-NM_0011272...
# 1233641      +  ID=exon-NM_001127208.3-6;Parent=rna-NM_0011272...
# 1233642      +  ID=exon-NM_001127208.3-7;Parent=rna-NM_0011272...
# 1233643      +  ID=exon-NM_001127208.3-8;Parent=rna-NM_0011272...
# 1233644      +  ID=exon-NM_001127208.3-9;Parent=rna-NM_0011272...
# 1233645      +  ID=exon-NM_001127208.3-10;Parent=rna-NM_001127...
# 1233646      +  ID=exon-NM_001127208.3-11;Parent=rna-NM_001127...
#
#                              ID         exon_parent exon_gbkey exon_gene  \
# 1233609      exon-NM_017628.4-1     rna-NM_017628.4       mRNA      TET2
# 1233610      exon-NM_017628.4-2     rna-NM_017628.4       mRNA      TET2
# 1233611      exon-NM_017628.4-3     rna-NM_017628.4       mRNA      TET2
# 1233636   exon-NM_001127208.3-1  rna-NM_001127208.3       mRNA      TET2
# 1233637   exon-NM_001127208.3-2  rna-NM_001127208.3       mRNA      TET2
# 1233638   exon-NM_001127208.3-3  rna-NM_001127208.3       mRNA      TET2
# 1233639   exon-NM_001127208.3-4  rna-NM_001127208.3       mRNA      TET2
# 1233640   exon-NM_001127208.3-5  rna-NM_001127208.3       mRNA      TET2
# 1233641   exon-NM_001127208.3-6  rna-NM_001127208.3       mRNA      TET2
# 1233642   exon-NM_001127208.3-7  rna-NM_001127208.3       mRNA      TET2
# 1233643   exon-NM_001127208.3-8  rna-NM_001127208.3       mRNA      TET2
# 1233644   exon-NM_001127208.3-9  rna-NM_001127208.3       mRNA      TET2
# 1233645  exon-NM_001127208.3-10  rna-NM_001127208.3       mRNA      TET2
# 1233646  exon-NM_001127208.3-11  rna-NM_001127208.3       mRNA      TET2
#
#         exon_transcript_id predicted
# 1233609        NM_017628.4        no
# 1233610        NM_017628.4        no
# 1233611        NM_017628.4        no
# 1233636     NM_001127208.3        no
# 1233637     NM_001127208.3        no
# 1233638     NM_001127208.3        no
# 1233639     NM_001127208.3        no
# 1233640     NM_001127208.3        no
# 1233641     NM_001127208.3        no
# 1233642     NM_001127208.3        no
# 1233643     NM_001127208.3        no
# 1233644     NM_001127208.3        no
# 1233645     NM_001127208.3        no
# 1233646     NM_001127208.3        no

# %% [markdown]
# Everything looks good, so write to file.

# %%
# Write it out.
restricted.to_csv(
    data_folder + filename + '.exon.processed',
    sep = '\t',
    index = False
)
